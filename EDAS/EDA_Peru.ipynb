# %%
import pandas as pd
import os

# %%
df_sismo = pd.read_csv('../DASHBOARD/CSV_ORIGINAL/raw_usgs_peru.csv', sep= ',')

# %%
df_sismo.head()
# Out:
#       type          id  properties.mag            properties.place  \
# 0  Feature  us6000kbqc             4.5   6 km NW of Paján, Ecuador
# 1  Feature  us6000kbad             4.3     31 km NE of Palca, Peru
# 2  Feature  us6000kaam             5.2  8 km W of Azogues, Ecuador
# 3  Feature  us6000ka4m             4.2               southern Peru
# 4  Feature  us7000jxn0             5.0  36 km NW of El Cardo, Peru
#
#            properties.time       properties.updated  properties.tz  \
# 0  2023-05-13 18:59:37.115  2023-05-13 19:22:32.040            NaN
# 1  2023-05-12 01:23:27.800  2023-05-12 01:52:36.040            NaN
# 2  2023-05-08 00:51:55.846  2023-05-09 04:35:04.934            NaN
# 3  2023-05-07 01:41:30.895  2023-05-07 02:08:28.040            NaN
# 4  2023-05-03 02:11:11.818  2023-05-03 23:39:32.040            NaN
#
#                                       properties.url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                    properties.detail  properties.felt  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...             23.0  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
#
#    properties.rms  properties.gap properties.magType properties.type  \
# 0            0.90           150.0                 mb      earthquake
# 1            0.45           115.0                 mb      earthquake
# 2            0.58            39.0                mww      earthquake
# 3            1.05           143.0                 mb      earthquake
# 4            0.60            97.0                 mb      earthquake
#
#                      properties.title  geometry.type  \
# 0   M 4.5 - 6 km NW of Paján, Ecuador          Point
# 1     M 4.3 - 31 km NE of Palca, Peru          Point
# 2  M 5.2 - 8 km W of Azogues, Ecuador          Point
# 3               M 4.2 - southern Peru          Point
# 4  M 5.0 - 36 km NW of El Cardo, Peru          Point
#
#             geometry.coordinates Longitud  Latitud Profundidad
# 0    [-80.4691, -1.5056, 43.612] -80.4691  -1.5056      43.612
# 1   [-69.721, -17.6075, 163.176] -69.7210 -17.6075     163.176
# 2    [-78.9266, -2.7512, 89.603] -78.9266  -2.7512      89.603
# 3  [-70.7804, -15.5297, 198.662] -70.7804 -15.5297     198.662
# 4   [-72.9786, -16.3846, 65.296] -72.9786 -16.3846      65.296
#
# [5 rows x 33 columns]

# %%
df_sismo.columns
# Out:
# Index(['type', 'id', 'properties.mag', 'properties.place', 'properties.time',
#        'properties.updated', 'properties.tz', 'properties.url',
#        'properties.detail', 'properties.felt', 'properties.cdi',
#        'properties.mmi', 'properties.alert', 'properties.status',
#        'properties.tsunami', 'properties.sig', 'properties.net',
#        'properties.code', 'properties.ids', 'properties.sources',
#        'properties.types', 'properties.nst', 'properties.dmin',
#        'properties.rms', 'properties.gap', 'properties.magType',
#        'properties.type', 'properties.title', 'geometry.type',
#        'geometry.coordinates', 'Longitud', 'Latitud', 'Profundidad'],
#       dtype='object')

# %%
df_sismo.drop(columns=['type','properties.tz','properties.code','properties.url','properties.detail','properties.alert','properties.net'
                       ,'properties.status','properties.types','properties.sources','properties.magType'
                       ,'properties.type', 'properties.title', 'geometry.type','geometry.coordinates','properties.ids'], axis=1, inplace=True)

# %%
df_sismo = df_sismo.rename(columns={"properties.mag": "Magnitud",
                                    "properties.time": "Primer reg",
                                    "properties.updated": "Ultimo registro",
                                    "properties.tsunami": "Posibilidad tsunami",
                                    "properties.sig": "Importancia del evento",
                                    "properties.dmin": "Dist Horizontal epicentro",
                                    "properties.gap": "Brecha azimutal",
                                    'properties.cdi': 'cdi',  
                                    'properties.mmi': 'mmi',  
                                    'properties.net': 'net',  
                                    'properties.code': 'code',
                                    'properties.nst': 'nst',
                                    'properties.rms': 'RMS',
                                    'properties.felt': 'felt'})
df_sismo.head(1)
# Out:
#            id  Magnitud           properties.place               Primer reg  \
# 0  us6000kbqc       4.5  6 km NW of Paján, Ecuador  2023-05-13 18:59:37.115
#
#            Ultimo registro  felt  cdi  mmi  Posibilidad tsunami  \
# 0  2023-05-13 19:22:32.040   NaN  NaN  NaN                    0
#
#    Importancia del evento   nst  Dist Horizontal epicentro  RMS  \
# 0                     312  69.0                      1.301  0.9
#
#    Brecha azimutal  Longitud  Latitud  Profundidad
# 0            150.0  -80.4691  -1.5056       43.612

# %%
df_sismo['Pais'] = df_sismo['properties.place'].str.split(',').str[1].str.strip()

df_sismo['properties.place'] = df_sismo['properties.place'].str.split(',', expand=True)[0]

# %%
df_sismo.head()
# Out:
#            id  Magnitud      properties.place               Primer reg  \
# 0  us6000kbqc       4.5      6 km NW of Paján  2023-05-13 18:59:37.115
# 1  us6000kbad       4.3     31 km NE of Palca  2023-05-12 01:23:27.800
# 2  us6000kaam       5.2     8 km W of Azogues  2023-05-08 00:51:55.846
# 3  us6000ka4m       4.2         southern Peru  2023-05-07 01:41:30.895
# 4  us7000jxn0       5.0  36 km NW of El Cardo  2023-05-03 02:11:11.818
#
#            Ultimo registro  felt  cdi  mmi  Posibilidad tsunami  \
# 0  2023-05-13 19:22:32.040   NaN  NaN  NaN                    0
# 1  2023-05-12 01:52:36.040   NaN  NaN  NaN                    0
# 2  2023-05-09 04:35:04.934  23.0  4.6  NaN                    0
# 3  2023-05-07 02:08:28.040   NaN  NaN  NaN                    0
# 4  2023-05-03 23:39:32.040   NaN  NaN  NaN                    0
#
#    Importancia del evento    nst  Dist Horizontal epicentro   RMS  \
# 0                     312   69.0                      1.301  0.90
# 1                     284   14.0                      0.231  0.45
# 2                     427  113.0                      1.250  0.58
# 3                     271   24.0                      2.398  1.05
# 4                     385   54.0                      3.200  0.60
#
#    Brecha azimutal  Longitud  Latitud  Profundidad     Pais
# 0            150.0  -80.4691  -1.5056       43.612  Ecuador
# 1            115.0  -69.7210 -17.6075      163.176     Peru
# 2             39.0  -78.9266  -2.7512       89.603  Ecuador
# 3            143.0  -70.7804 -15.5297      198.662      NaN
# 4             97.0  -72.9786 -16.3846       65.296     Peru

# %%
folder_path = "../DASHBOARD/CSV_TRANSFORMADOS"
file_name = "Datos_Peru_USGS.csv"
file_path = os.path.join(folder_path, file_name)

df_sismo.to_csv(file_path, index=False)
